# %%
x = 20
type(x), x
# Out:
# (int, 20)

# %%
x = 20.3
type(x), x
# Out:
# (float, 20.3)

# %%
x = True
type(x), x
# Out:
# (bool, True)

# %%
x = "Hello"
type(x), x
# Out:
# (str, 'Hello')

# %%
x = 'Hello'
type(x), x
# Out:
# (str, 'Hello')

# %%
x = """Hello



"""
type(x), x
# Out:
# (str, 'Hello\n\n\n\n')
